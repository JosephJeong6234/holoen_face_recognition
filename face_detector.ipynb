# %%
# %%capture
# !git clone https://github.com/qhgz2013/anime-face-detector.git
# !pip install tensorflow
# !pip install opencv-python
# !pip install cython
#xcode-select --install

# %%
#vtuberList = ["ame","bae","calli","fauna","gura","ina","irys","kiara","kronii","mumei"]
# !python main.py -i data/ame -o /data/ame/ame.json
# !python main.py -i data/bae -o /data/bae/bae.json
# !python main.py -i data/calli -o /data/calli/calli.json
# !python main.py -i data/fauna -o /data/fauna/fauna.json
# !python main.py -i data/gura -o /data/gura/gura.json
# !python main.py -i data/ina -o /data/ina/ina.json
# !python main.py -i data/irys -o /data/irys/irys.json
# !python main.py -i data/kiara -o /data/kiara/kiara.json
# !python main.py -i data/kronii -o /data/kronii/kronii.json
# !python main.py -i data/mumei -o /data/mumei/mumei.json
# Out:
# 2023-06-14 15:07:03.822795: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# ...

# %%
# %cd ..
# Out:
# /Users/jjeong/tem_vchuba_faces/anime-face-detector

# %%
# %cd anime-face-detector/
# Out:
# /Users/jjeong/tem_vchuba_faces/anime-face-detector

# %%
# !make
# Out:
# python setup.py build_ext --inplace
# running build_ext
# cythoning nms/cpu_nms.pyx to nms/cpu_nms.c
# /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /Users/jjeong/tem_vchuba_faces/anime-face-detector/nms/cpu_nms.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'nms.cpu_nms' extension
# creating build
# creating build/temp.macosx-10.9-x86_64-3.8
# creating build/temp.macosx-10.9-x86_64-3.8/nms
# gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/jjeong/opt/anaconda3/include -arch x86_64 -I/Users/jjeong/opt/anaconda3/include -arch x86_64 -I/Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/numpy/core/include -I/Users/jjeong/opt/anaconda3/include/python3.8 -c nms/cpu_nms.c -o build/temp.macosx-10.9-x86_64-3.8/nms/cpu_nms.o
# ...

# %%
# %cd anime-face-detector/
# Out:
# /Users/jjeong/tem_vchuba_faces/anime-face-detector

# %%
# %cd ame.json
# Out:
# [Errno 20] Not a directory: 'ame.json'
# /Users/jjeong/tem_vchuba_faces/anime-face-detector/data/ame

# %%
# !python main.py -i data/ame -o /data/ame/ame.json
# Out:
# 2023-06-14 20:24:51.001934: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# ...

# %%
# !python main.py -i '/data/ame/frame0Amelia Watson Moments That Give Me Life HololiveEN Clips.mp4.jpg' -o /data/ame/ame.json
# Out:
# 2023-06-14 20:39:11.351247: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Traceback (most recent call last):
#   File "main.py", line 189, in <module>
#     main()
#   File "main.py", line 103, in main
#     assert os.path.exists(args.input), 'The input path does not exists'
# AssertionError: The input path does not exists

# %%
# %ls
# Out:
# LICENSE                 data/                   nms_wrapper.py
# Makefile                faster_rcnn_wrapper.py  output.json
# README.md               main.py                 setup.py
# __pycache__/            make.bat                tf_contrib/
# _tf_compat_import.py    model/
# asset/                  nms/

# %%
# %cd anime-face-detector/
# Out:
# /Users/jjeong/tem_vchuba_faces/anime-face-detector

# %%
# !python anime-face-detector/main.py -i 'frame0Amelia Watson Moments That Give Me Life HololiveEN Clips-Copy1.mp4.jpg' -o anime-face-detector/output.json
# Out:
# 2023-06-14 20:54:56.390808: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Traceback (most recent call last):
#   File "anime-face-detector/main.py", line 189, in <module>
#     main()
#   File "anime-face-detector/main.py", line 103, in main
#     assert os.path.exists(args.input), 'The input path does not exists'
# AssertionError: The input path does not exists

# %%
# !python main.py -i data/ame -crop-location data/ame/cropped/ -start-output 1
# Out:
# 2023-06-14 21:22:41.600066: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# ...

# %%
import os

# %%
print(os.path.exists('/data/ame'))
# Out:
# False

# %%
# !python main.py -i data/bae -crop-location data/bae/cropped/ -start-output 1
# Out:
# 2023-06-14 22:05:44.946718: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# ...

# %%
#vtuberList = ["ame","bae","calli","fauna","gura","ina","irys","kiara","kronii","mumei"]
#!python main.py -i data/calli -crop-location data/calli/cropped/ -start-output 1
# !python main.py -i data/fauna -crop-location data/fauna/cropped/ -start-output 1
# !python main.py -i data/gura -crop-location data/gura/cropped/ -start-output 1
# !python main.py -i data/ina -crop-location data/ina/cropped/ -start-output 1
# !python main.py -i data/irys -crop-location data/irys/cropped/ -start-output 1
# !python main.py -i data/kiara -crop-location data/kiara/cropped/ -start-output 1
# !python main.py -i data/kronii -crop-location data/kronii/cropped/ -start-output 1
# !python main.py -i data/mumei -crop-location data/mumei/cropped/ -start-output 1
# Out:
# 2023-06-15 00:01:39.645845: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# ...

# %%
# !python main.py -i data/'Screenshot 2023-06-14 at 9.21.38 PM.png' -crop-location data/ -start-output 1
# Out:
# 2023-06-14 23:36:05.546407: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# ...

# %%
# !python main.py -i 'data/Screenshot 2023-06-14 at 9.21.38 PM.png' -crop-location data/ -start-output 1
# Out:
# ^C

# %%
# !python main.py -i data/irys -crop-location data/irys/cropped/ -start-output 1
# Out:
# 2023-06-15 16:07:28.610592: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# /Users/jjeong/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# ...
